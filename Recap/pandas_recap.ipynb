# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A', 'B', 'C'], index=['X', 'Y', 'Z'])
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index.to_list()
# Out:
# ['X', 'Y', 'Z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape
# Out:
# (3, 3)

# %%
results = pd.read_parquet('Datasets/results.parquet')
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
coffee = pd.read_csv('Datasets/coffee.csv')
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[1,2,6]]
# Out:
#         Day Coffee Type  Units Sold
# 1    Monday       Latte          15
# 2   Tuesday    Espresso          30
# 6  Thursday    Espresso          40

# %%
coffee.loc[5:]
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[5:8]
# Out:
#          Day Coffee Type  Units Sold
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45

# %%
coffee.iloc[0:5, [0,2]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[1, 'Units Sold'] = 10

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.at[0, 'Units Sold']
# Out:
# np.int64(25)

# %%
coffee.iat[0, 2]
# Out:
# np.int64(25)

# %%
coffee['Day']
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.sort_values('Units Sold', ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          10

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row)
    print('\n\n\n')
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
#
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# ...

# %%
bios = pd.read_csv('Datasets/bios.csv')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios['height_cm'] >= 220, ['name', 'height_cm']]
# Out:
#                       name  height_cm
# 5089    Viktor Pankrashkin      220.0
# 5673        Gunther Behnke      221.0
# 5781        Tommy Burleson      223.0
# 6504           Luc Longley      220.0
# 6978       Arvydas Sabonis      223.0
# 7188    Vladimir Tkachenko      220.0
# 89070             Yao Ming      226.0
# 89075       Roberto Dueñas      221.0
# 120266        Zhang Zhaoxu      221.0

# %%
bios[bios['height_cm'] >= 220] [['name', 'height_cm']]
# Out:
#                       name  height_cm
# 5089    Viktor Pankrashkin      220.0
# 5673        Gunther Behnke      221.0
# 5781        Tommy Burleson      223.0
# 6504           Luc Longley      220.0
# 6978       Arvydas Sabonis      223.0
# 7188    Vladimir Tkachenko      220.0
# 89070             Yao Ming      226.0
# 89075       Roberto Dueñas      221.0
# 120266        Zhang Zhaoxu      221.0

# %%
bios[(bios['height_cm'] >= 220) & (bios['born_country']=='USA')]
# Out:
#       athlete_id            name   born_date  born_city     born_region  \
# 5781        5804  Tommy Burleson  1952-02-24  Crossnore  North Carolina
#
#      born_country            NOC  height_cm  weight_kg died_date
# 5781          USA  United States      223.0      102.0       NaN

# %%
bios[bios['name'].str.contains('Tom|Patrick', case=False)]
# Out:
#         athlete_id               name   born_date    born_city  \
# 6                7      Patrick Chila  1969-11-27  Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20      Vryheid
# 319            320  Patrick De Koning  1961-04-23  Dendermonde
# 442            443   Tomi Poikolainen  1961-12-27     Helsinki
# 445            446      Tommi Tuovila  1971-07-08      Kuusamo
# ...            ...                ...         ...          ...
# 145060      148772    Mariya Istomina  1997-03-20      Ust-Bub
# 145245      148964    Tomáš Sklenárik  1999-10-13       Revúca
# 145261      148981        Matej Tomek  1997-05-24   Bratislava
# 145435      149158  Patrick Gasienica  1998-11-28      McHenry
# 145473      149200     Toms Andersons  1993-11-25         Rīga
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 6                 Essonne          FRA         France      180.0       73.0
# ...

# %%
bios[bios['name'].str.contains(r'^[AEOIUaeoiu]')]
# Out:
#         athlete_id                    name   born_date        born_city  \
# 1                2          Arnaud Boetsch  1969-04-01           Meulan
# 4                5            Albert Canet  1878-04-17       Wandsworth
# 15              16  Adrien Fauchier-Magnan  1873-11-19      Paris VIIIe
# 19              20            André Gobert  1890-09-30      Paris XVIIe
# 28              29         Albert Lippmann         NaN              NaN
# ...            ...                     ...         ...              ...
# 145450      149174       Anna Shcherbakova  2004-03-28  Moskva (Moscow)
# 145454      149180           Anna Hoffmann  2000-03-28          Madison
# 145457      149183          Alix Wilkinson  2000-08-02    Mammoth Lakes
# 145467      149194             Elisa Nakab  1998-05-08         Briançon
# 145498      149225          André Foussard  1899-05-19            Niort
#
#          born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['born_country'].isin(['USA'])]
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# ...

# %%
bios.query('born_country == "USA" and born_city == "Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %%
coffee['price'] = 4.99
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          10   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
import numpy as np
coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  new_price
# 0     Monday    Espresso          25   4.99       3.99
# 1     Monday       Latte          10   4.99       5.99
# 2    Tuesday    Espresso          30   4.99       3.99
# 3    Tuesday       Latte          20   4.99       5.99
# 4  Wednesday    Espresso          35   4.99       3.99

# %%
coffee.drop(columns='price', inplace=True)
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          10       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
coffee_new = coffee.copy()
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          10       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
coffee['Revenue'] = coffee['Units Sold'] * coffee['new_price']
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          10       5.99    59.90
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={'new_price':'Price'}, inplace=True)
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          10   5.99    59.90
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
bios_new = bios.copy()
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
bios_new.query('first_name == "Ben"').head()
# Out:
#       athlete_id           name   born_date    born_city    born_region  \
# 4673        4690       Ben Bril  1912-07-16    Amsterdam  Noord-Holland
# 8020        8061      Ben Sisay  1956-03-11          NaN            NaN
# 8626        8673       Ben Funk  1902-06-02  Bloomington       Illinois
# 8711        8758   Ben Rothwell  1902-09-14   West Point       Virginia
# 8733        8780  Ben Spradling  1879-01-18   Washington       Missouri
#
#      born_country            NOC  height_cm  weight_kg   died_date first_name
# 4673          NED    Netherlands        NaN        NaN  2003-09-11        Ben
# 8020          NaN   Sierra Leone      187.0       67.0         NaN        Ben
# 8626          USA  United States        NaN        NaN  1969-01-01        Ben
# 8711          USA  United States      174.0       61.0  1979-12-14        Ben
# 8733          USA  United States        NaN        NaN         NaN        Ben

# %%
bios_new['born_date'] = pd.to_datetime(bios_new['born_date'])
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  datetime64[ns]
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 12.2+ MB

# %%
bios_new['born_year'] = bios_new['born_date'].dt.year
bios_new.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name  born_year
# 0  1960-10-02  Jean-François     1886.0
# 1         NaN         Arnaud     1969.0
# 2  1994-07-17           Jean     1898.0
# ...

# %%
bios_new['born_month'] = bios_new['born_date'].dt.month
bios_new.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name  born_year  born_month
# 0  1960-10-02  Jean-François     1886.0        12.0
# 1         NaN         Arnaud     1969.0         4.0
# ...

# %%
bios_new['born_day'] = bios_new['born_date'].dt.day
bios_new.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name  born_year  born_month  born_day
# 0  1960-10-02  Jean-François     1886.0        12.0      12.0
# 1         NaN         Arnaud     1969.0         4.0       1.0
# ...

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x<170 else ('Average' if x<180 else 'Tall'))
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN            Tall
# 2  1994-07-17            Tall
# 3  1978-03-20           Short
# 4  1930-07-25            Tall

# %%
nocs = pd.read_csv('Datasets/noc_regions.csv')
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left', suffixes=['bios', 'noc'])
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country NOCbios  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category NOCnoc  region notes
# 0  1960-10-02            Tall    FRA  France   NaN
# 1         NaN            Tall    FRA  France   NaN
# ...

# %%
bios_new.rename(columns={'region':'born_country_full'}, inplace=True)
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country NOCbios  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category NOCnoc born_country_full notes
# 0  1960-10-02            Tall    FRA            France   NaN
# 1         NaN            Tall    FRA            France   NaN
# ...

# %%
usa  = bios[bios['born_country'] == 'USA'].copy()
gbr  = bios[bios['born_country'] == 'GBR'].copy()

# %%
usa.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_category
# 54           Average
# 960          Average
# 961            Short
# ...

# %%
gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country            NOC  height_cm  weight_kg   died_date  \
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10
# 39          GBR  Great Britain        NaN        NaN  1970-02-22
# 40          GBR  Great Britain      175.0       64.0         NaN
#
#    height_category
# 4             Tall
# 37            Tall
# 38            Tall
# 39            Tall
# 40         Average

# %%
usa_gbr = pd.concat([usa, gbr])
usa_gbr.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_category
# 54           Average
# 960          Average
# 961            Short
# ...

# %%
usa_gbr.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_category
# 144811            Tall
# ...

# %%
combined_df = pd.merge(results, bios, on='athlete_id', how='left')
combined_df.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied  ...                   name  \
# 0           1  FRA             None   17.0   True  ...  Jean-François Blanchy
# 1           1  FRA   Jean Montariol    NaN  False  ...  Jean-François Blanchy
# 2           1  FRA             None   32.0   True  ...  Jean-François Blanchy
# 3           1  FRA  Jeanne Vaussard    8.0   True  ...  Jean-François Blanchy
# 4           1  FRA  Jacques Brugnon    4.0  False  ...  Jean-François Blanchy
#
# ...

# %%
coffee.loc[[2,3], 'Units Sold'] = np.nan
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso        25.0   3.99    99.75
# 1     Monday       Latte        10.0   5.99    59.90
# 2    Tuesday    Espresso         NaN   3.99   119.70
# 3    Tuesday       Latte         NaN   5.99   119.80
# 4  Wednesday    Espresso        35.0   3.99   139.65

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# Price          0
# Revenue        0
# dtype: int64

# %%
coffee.fillna(100)
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0   3.99    99.75
# 1      Monday       Latte        10.0   5.99    59.90
# 2     Tuesday    Espresso       100.0   3.99   119.70
# 3     Tuesday       Latte       100.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso       25.00   3.99    99.75
# 1      Monday       Latte       10.00   5.99    59.90
# 2     Tuesday    Espresso       33.75   3.99   119.70
# 3     Tuesday       Latte       33.75   5.99   119.80
# 4   Wednesday    Espresso       35.00   3.99   139.65
# 5   Wednesday       Latte       25.00   5.99   149.75
# 6    Thursday    Espresso       40.00   3.99   159.60
# 7    Thursday       Latte       30.00   5.99   179.70
# 8      Friday    Espresso       45.00   3.99   179.55
# 9      Friday       Latte       35.00   5.99   209.65
# 10   Saturday    Espresso       45.00   3.99   179.55
# 11   Saturday       Latte       35.00   5.99   209.65
# 12     Sunday    Espresso       45.00   3.99   179.55
# 13     Sunday       Latte       35.00   5.99   209.65

# %%
coffee['Units Sold'].interpolate()
# Out:
# 0     25.000000
# 1     10.000000
# 2     18.333333
# 3     26.666667
# 4     35.000000
# 5     25.000000
# 6     40.000000
# 7     30.000000
# 8     45.000000
# 9     35.000000
# 10    45.000000
# 11    35.000000
# 12    45.000000
# 13    35.000000
# Name: Units Sold, dtype: float64

# %%
coffee.dropna()
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0   3.99    99.75
# 1      Monday       Latte        10.0   5.99    59.90
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#        Day Coffee Type  Units Sold  Price  Revenue
# 2  Tuesday    Espresso         NaN   3.99    119.7
# 3  Tuesday       Latte         NaN   5.99    119.8

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0   3.99    99.75
# 1      Monday       Latte        10.0   5.99    59.90
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Pennsylvania             530
# Massachusetts            530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    235.0
# Latte       170.0
# Name: Units Sold, dtype: float64

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso        25.0   3.99    99.75
# 1     Monday       Latte        10.0   5.99    59.90
# 2    Tuesday    Espresso         NaN   3.99   119.70
# 3    Tuesday       Latte         NaN   5.99   119.80
# 4  Wednesday    Espresso        35.0   3.99   139.65

# %%
pivot = coffee.pivot(columns='Coffee Type', index='Day', values='Revenue')
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  209.65
# Monday          99.75   59.90
# Saturday       179.55  209.65
# Sunday         179.55  209.65
# Thursday       159.60  179.70
# Tuesday        119.70  119.80
# Wednesday      139.65  149.75

# %%
pivot.loc['Monday', 'Latte']
# Out:
# np.float64(59.900000000000006)

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso    1057.35
# Latte       1138.10
# dtype: float64

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       389.20
# Monday       159.65
# Saturday     389.20
# Sunday       389.20
# Thursday     339.30
# Tuesday      239.50
# Wednesday    289.40
# dtype: float64

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])
bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 5       1838.0     1
# 4       1837.0     1
# 3       1836.0     1
# 2       1833.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]
